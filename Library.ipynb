# %%
x = input().strip()
print(x)
# Out:
# dsdsw

# %%
x = 5 + 6
x = "hello world!"
print(f"5 + 6 equals {5 + 6}")
"""
[155] - Dostoevsky
Book List:
- Date: [1940], Title: Crime & Punishment
- [2015] The Idiot
- [1800] Notes From Underground

"""
## Checking about the String when you print about a book or bought books or borrowed books
# Out:
# 5 + 6 equals 11
# '\n[155] - Dostoevsky\nBook List:\n- Date: [1940], Title: Crime & Punishment\n- [2015] The Idiot\n- [1800] Notes From Underground\n\n'

# %%
class User:
    def __init__(self, id, name, age):
        self.id = id
        self.name = name
        self.age = age
        self.borrowed = [] # Objects not strings
        self.bought = []
# learning list comprehension, join, & format string
    def __str__(self):
        borrowedbooks = "\n".join([f"- Date: [{book.publish_date}], Title: {book.name}" for book in self.borrowed])
        boughtbooks = "\n".join([f"- Date: [{book.publish_date}], Title: {book.name}" for book in self.bought])
        return f"[{self.id}] - {self.name}\n ## Borrowed Books:\n{borrowedbooks}\n## Bought Books:\n{boughtbooks}"
        
    def __len__(self):
        return len(self.borrowed)

class Author:
    def __init__(self, id, name):
        self.id = id
        self.name = name
        self.booklist = []
# learning list comprehension    
    def __str__(self):
        listing_books = "\n".join([f"- [{book.publish_date}] {book.name}" for book in {self.booklist}])
        return f"[{self.id}] - {self.name}\n## Book List:\n{listing_books}"
    
    def __len__(self):
        return len(self.booklist)

class Book:
    def __init__(self, id, name, author, category, department, publish, publisher, price):
        self.id = id
        self.name = name
        self.author = author
        self.category = category
        self.department = department
        self.publish_date = publish
        self.publisher = publisher
        self.price = price
        self.collection = None
    
    def __str__(self):
        return f"[{self.publish_date}] - {self.name}\nAuthor: {self.author}\nCategory: {self.category}\nDepartment: {self.department}"
    
    def __len__(self):
        return self.price


class Library:
    def __init__(self):
        self.booklist = []
        self.authors = []

    def __str__(self):
        pass

    def __len__(self):
        return len(self.booklist)

    def add_books(self):
        book_id = len(Library) + 1
        name = input("Title: ").strip().title()
        author = input("Author Name: ").strip().title()
        category = input("Category: ").strip().title()
        department = input("Department: ").strip().title()
        publish_date = input("Publish Date: ").strip()
        publisher = input("Publisher: ").strip().title()
        price = int(input("Price"))
        new_book = Book(book_id, name, author, category, department, publish_date, publisher, price)
        self.booklist.append(new_book)
        for author_name in self.authors:
            if author_name.name == author:
                pass
            """ elif :
                pass 
            else:
                pass"""
